# %% [markdown]
# # Analyzing Denver's 2010 Census Data
#
# ## Goals:
# Play with data. Clean the data. Visualize it.
#
#
# ### Data Source:
# http://localhost:8888/?token=bba1269b06a3677ab4812fb846c63b5636d017b4b8a701ad

# %% [markdown]
# ## Set Up the Environment and Load the Data

# %%
import pandas as pd

# %%
# read data from csv
df = pd.read_csv('census_neighborhood_demographics_2010.csv', index_col='NBHD_ID').sort_index()

# %%
# make sure all columns are displayed
pd.options.display.max_columns = None

# %% [markdown]
# ## Explore, Format and Clean the Data

# %%
# display first 5 rows
df.head()
# Out:
#           nbrhd name  population  hispanic   white  black  nativeam  asian  \
# nbhd id
# 1        Athmar Park      8898.0    6499.0  1832.0  102.0      67.0  314.0
# 2            Auraria       705.0      62.0   555.0   27.0       5.0   29.0
# 3              Baker      4879.0    1664.0  2854.0  144.0      43.0   52.0
# 4             Barnum      6111.0    4808.0  1101.0   47.0      44.0   51.0
# 5        Barnum West      5376.0    4016.0  1151.0   40.0      53.0   81.0
#
#          hawpacis  other  two or more    male  female  age 0 to 9  \
# nbhd id
# 1             8.0   14.0         62.0  4597.0  4301.0      1596.0
# 2             2.0    1.0         24.0   352.0   353.0         1.0
# 3            10.0    7.0        105.0  2565.0  2314.0       463.0
# 4             0.0   17.0         43.0  3144.0  2967.0      1197.0
# 5             2.0    5.0         28.0  2754.0  2622.0       920.0
#
#          age 10 to 19  age 20 to 29  age 30 to 39  age 40 to 49  age 50 to 59  \
# nbhd id
# 1              1340.0        1384.0        1487.0        1123.0         893.0
# 2               430.0         204.0          21.0          12.0          21.0
# 3               360.0        1029.0        1179.0         684.0         615.0
# 4              1020.0         951.0         997.0         803.0         563.0
# 5               829.0         853.0         711.0         696.0         582.0
#
#          age 60 to 69  age 70 to 79  age 80 plus  age less 18  age 65 plus  \
# nbhd id
# 1               553.0         291.0        231.0       2649.0        731.0
# 2                12.0           3.0          1.0          7.0          6.0
# 3               340.0         138.0         71.0        745.0        335.0
# 4               331.0         162.0         87.0       2015.0        360.0
# 5               371.0         271.0        143.0       1579.0        593.0
#
#          percent 20-29
# nbhd id
# 1                15.55
# 2                28.94
# 3                21.09
# 4                15.56
# 5                15.87

# %%
# display overview stats about rows
df.describe()
# Out:
#        POPULATION_2010  HISPANIC_2010    WHITE_2010   BLACK_2010  \
# count        78.000000      78.000000     78.000000    78.000000
# mean       7694.333333    2448.269231   4012.974359   748.564103
# std        5166.830998    3039.875278   2814.578735  1476.224489
# min         705.000000      62.000000    111.000000    20.000000
# 25%        4213.000000     495.500000   1781.000000    89.500000
# 50%        6701.500000    1611.000000   3310.000000   237.000000
# 75%        9640.000000    2841.250000   5874.250000   726.750000
# max       30348.000000   17855.000000  11750.000000  8605.000000
#
#        NATIVEAM_2010   ASIAN_2010  HAWPACIS_2010  OTHER_2010  \
# count      78.000000    78.000000      78.000000   78.000000
# mean       45.192308   255.448718       6.346154   15.487179
# std        33.159613   278.218108      13.482867   11.967210
# min         2.000000    20.000000       0.000000    0.000000
# 25%        18.250000    77.250000       1.250000    6.000000
# min       0.990000     0.850000       60.000000      37.000000
# 25%      14.625000     6.847500     1773.750000     610.500000
# 50%      19.115000     9.845000     3086.000000    1006.000000
# 75%      26.322500    13.355000     3985.750000    1653.250000
# max      54.010000    26.870000    10856.000000    7796.000000
#
#        ONE_PERSON_HH_MALE  ONE_PERSON_HH_FEMALE  TWO_OR_MORE_PERSON_HH  \
# count           78.000000             78.000000              78.000000
# mean           662.205128            707.384615            2003.576923
# std            653.108061            604.783942            1286.550745
# min             27.000000             10.000000              23.000000
# 25%            290.000000            321.250000            1103.750000
# 50%            453.500000            561.000000            1894.500000
# 75%            785.250000            865.250000            2547.500000
# max           4530.000000           3266.000000            7608.000000
#
#        FAMILY_HHLD  HUSB_WIFE_FAM  HUSB_WIFE_NO_CHILD  HUSB_WIFE_W_CHLDR  \
# count    78.000000      78.000000           78.000000          78.000000
# mean   1602.615385    1099.320513          485.474359         613.846154
# std    1183.566251     827.955995          480.004944         410.372529
# min      15.000000      13.000000            1.000000          12.000000
# 25%     855.000000     550.250000          196.500000         302.750000
# 50%    1290.000000     962.000000          387.500000         574.000000
# 75%    2095.000000    1437.000000          619.750000         828.250000
# max    7056.000000    4907.000000         3051.000000        2008.000000
#
#        OTHER_FAMILY  MALE_HHLDR_NO_WIFE  MALE_HHLDR_W_CHLDR  \
# count     78.000000           78.000000           78.000000
# mean     503.294872          146.602564           66.512821
# std      403.857475          114.676432           56.468298
# min        2.000000            0.000000            0.000000
# 25%      234.500000           76.750000           29.250000
# 50%      401.500000          117.500000           55.500000
# 75%      683.250000          205.500000           87.750000
# max     2296.000000          659.000000          353.000000
#
#        MALE_HHLDR_NO_CHILDR  FEMALE_HHLDR_NO_HUSB  FEMALE_HHLDR_W_CHILDR  \
# count             78.000000             78.000000              78.000000
# mean              80.089744            356.692308             200.051282
# std               61.283710            293.310540             185.862741
# min                0.000000              2.000000               1.000000
# 25%               36.000000            163.750000              76.750000
# 50%               61.000000            285.000000             156.500000
# 75%              107.500000            488.250000             262.000000
# max              364.000000           1637.000000            1102.000000
#
#        FEMALE_HHLDR_NO_CHILDR  NON_FAMILY_HH  NON_FAMILY_MALE_HHLDR  \
# count               78.000000      78.000000              78.000000
# mean               156.641026     400.961538             226.435897
# std                115.812542     315.352305             178.368697
# min                  1.000000       7.000000               2.000000
# 25%                 78.000000     194.250000             109.750000
# 50%                128.500000     325.000000             187.500000
# 75%                207.750000     526.750000             284.500000
# max                659.000000    1859.000000            1034.000000
#
#        NON_FAMILY_FEMALE_HHLDR  HH_W_NONRELATIVES  HH_NO_NONRELATIVES  \
# count                78.000000          78.000000           78.000000
# mean                174.525641         540.474359         2832.692308
# std                 139.106679         350.857677         1833.137133
# min                   3.000000           8.000000           52.000000
# 25%                  81.000000         291.750000         1464.500000
# 50%                 138.500000         463.500000         2668.500000
# 75%                 240.500000         701.500000         3370.500000
# max                 825.000000        1941.000000         8915.000000
#
#           FAMILIES  POP_GROUP_QRTRS  GQ_INSTITUTIONALIZED  \
# count    78.000000        78.000000             78.000000
# mean   1602.615385       204.884615             83.564103
# std    1183.566251       480.107915            373.432606
# min      15.000000         0.000000              0.000000
# 25%     855.000000         2.000000              0.000000
# 50%    1290.000000        35.500000              0.000000
# 75%    2095.000000       178.000000             56.750000
# max    7056.000000      3275.000000           3273.000000
#
#        GQ_CORRECTIONAL_FAC  GQ_JUVENILE_FAC  GQ_NURSING_FAC  \
# count            78.000000        78.000000       78.000000
# mean             49.115385         3.333333       29.910256
# std             370.603368        10.341778       61.932973
# min               0.000000         0.000000        0.000000
# 25%               0.000000         0.000000        0.000000
# 50%               0.000000         0.000000        0.000000
# 75%               0.000000         0.000000       24.250000
# max            3273.000000        50.000000      304.000000
#
#        GQ_OTHER_INST_FAC  GQ_NONINSTITUTIONAL  GQ_COLLEGEHOUSING  \
# count          78.000000            78.000000          78.000000
# mean            1.205128           121.320513          63.333333
# std             7.504733           316.703577         268.324511
# min             0.000000             0.000000           0.000000
# 25%             0.000000             0.000000           0.000000
# 50%             0.000000            10.000000           0.000000
# 75%             0.000000            40.000000           0.000000
# max            51.000000          2121.000000        2121.000000
#
#        GQ_MILITARYQUARTERS  GQ_OTHER_NONINST  HOUSING_UNITS   OCCUPIED_HU  \
# count                 78.0         78.000000      78.000000     78.000000
# mean                   0.0         57.987179    3664.064103   3373.166667
# std                    0.0        180.559915    2306.892785   2145.793889
# min                    0.0          0.000000      69.000000     60.000000
# 25%                    0.0          0.000000    1865.000000   1773.750000
# 50%                    0.0          6.500000    3358.000000   3086.000000
# 75%                    0.0         26.000000    4292.250000   3985.750000
# max                    0.0       1386.000000   11757.000000  10856.000000
#
#          VACANT_HU  OWNED_W_MORTG_LOAN  OWNED_FREE_CLEAR       RENTED  \
# count    78.000000           78.000000         78.000000    78.000000
# mean    290.897436         1333.320513        352.948718  1686.897436
# std     210.379780          997.917591        283.332529  1402.168993
# min       9.000000           10.000000          2.000000    21.000000
# 25%     158.250000          663.000000        164.750000   729.750000
# 50%     225.500000         1199.500000        300.500000  1375.000000
# 75%     362.000000         1767.500000        458.250000  2104.000000
# max    1006.000000         6471.000000       1462.000000  8648.000000
#
#        VACANT_FOR_RENT  VACANT_RENTED_NOT_OCC  VACANT_FOR_SALE  \
# count        78.000000              78.000000        78.000000
# mean        131.948718               6.448718        62.897436
# std         129.054091               6.399366        65.140725
# min           3.000000               0.000000         1.000000
# 25%          41.250000               2.000000        29.000000
# 50%          84.500000               4.500000        49.500000
# 75%         186.000000               8.750000        71.250000
# max         587.000000              35.000000       501.000000
#
#        VACANT_SOLD_NOT_OCC  VACANT_SEASONAL  VACANT_MIGRANT_WRKR  \
# count            78.000000        78.000000            78.000000
# mean              9.461538        27.756410             0.025641
# std               6.468088        44.818012             0.226455
# min               0.000000         0.000000             0.000000
# 25%               5.000000         4.000000             0.000000
# 50%               8.000000        11.000000             0.000000
# 75%              12.750000        30.000000             0.000000
# max              28.000000       284.000000             2.000000
#
#        VACANT_OTHER     HU_OWNED  OWNED_AGE_15_TO_24  OWNED_AGE_25_TO_34  \
# count     78.000000    78.000000           78.000000           78.000000
# mean      52.358974  1686.269231           22.102564          271.397436
# std       35.123890  1162.654929           25.248166          227.787856
# min        0.000000    17.000000            0.000000            1.000000
# 25%       25.000000   822.250000           10.250000          132.250000
# 50%       44.500000  1576.500000           16.000000          228.000000
# 75%       70.000000  2197.750000           24.750000          346.250000
# max      158.000000  6650.000000          169.000000         1602.000000
#
#        OWNED_AGE_35_TO_44  OWNED_AGE_45_TO_54  OWNED_AGE_55_TO_59  \
# count           78.000000           78.000000           78.000000
# mean           358.256410          325.500000          174.435897
# std            311.695591          249.806042          120.329482
# min              2.000000            1.000000            0.000000
# 25%            182.000000          159.750000           85.500000
# 50%            283.500000          284.000000          158.500000
# 75%            491.750000          416.250000          236.500000
# max           2071.000000         1513.000000          573.000000
#
#        OWNED_AGE_60_TO_64  OWNED_AGE_65_TO_74  OWNED_AGE_75_TO_84  \
# count           78.000000           78.000000           78.000000
# mean           160.230769          188.564103          129.794872
# std            114.420610          152.793519          137.345744
# min              1.000000            0.000000            0.000000
# 25%             72.500000           93.250000           52.750000
# 50%            152.500000          151.000000           90.500000
# 75%            201.750000          225.500000          153.250000
# max            551.000000          797.000000          818.000000
#
#        OWNED_AGE_85_PLUS    HU_RENTED  RENTED_AGE_15_TO_24  \
# count          78.000000    78.000000            78.000000
# mean           55.987179  1686.897436           217.615385
# std            65.195907  1402.168993           248.586823
# min             0.000000    21.000000             4.000000
# 25%            18.250000   729.750000            61.500000
# 50%            36.500000  1375.000000           116.000000
# 75%            78.500000  2104.000000           314.000000
# max           478.000000  8648.000000          1536.000000
#
#        RENTED_AGE_25_TO_34  RENTED_AGE_35_TO_44  RENTED_AGE_45_TO_54  \
# count            78.000000            78.000000            78.000000
# mean            570.141026           306.358974           232.666667
# std             573.003813           231.163515           169.866920
# min               6.000000             5.000000             4.000000
# 25%             213.500000           145.000000           117.250000
# 50%             422.500000           253.000000           180.000000
# 75%             665.750000           377.500000           295.750000
# max            3761.000000          1220.000000           896.000000
#
#        RENTED_AGE_55_TO_59  RENTED_AGE_60_TO_64  RENTED_AGE_65_TO_74  \
# count            78.000000            78.000000            78.000000
# mean             98.038462            78.102564            89.256410
# std              76.590231            61.972468            74.744662
# min               2.000000             0.000000             0.000000
# 25%              46.250000            36.000000            31.750000
# 50%              77.000000            58.000000            67.000000
# 75%             134.000000            99.250000           133.000000
# max             457.000000           347.000000           297.000000
#
#        RENTED_AGE_75_TO_84  RENTED_AGE_85_PLUS  SHAPE_Length  SHAPE_Area
# count            78.000000           78.000000     78.000000   78.000000
# mean             57.435897           37.282051      0.098506    0.000539
# std              56.443188           51.866687      0.076693    0.001305
# min               0.000000            0.000000      0.040371    0.000083
# 25%              17.250000            7.000000      0.061477    0.000210
# 50%              36.500000           14.000000      0.082002    0.000305
# 75%              84.000000           45.000000      0.110171    0.000411
# max             246.000000          229.000000      0.632612    0.011454

# %%
# check total number of rows and columns
df.shape
# Out:
# (78, 126)

# %%
# see if there are any null values
df.isnull().values.any()
# Out:
# False

# %%
# see if any rows contain duplicate data
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [NBRHD_NAME, POPULATION_2010, HISPANIC_2010, WHITE_2010, BLACK_2010, NATIVEAM_2010, ASIAN_2010, HAWPACIS_2010, OTHER_2010, TWO_OR_MORE_2010, PCT_HISPANIC, PCT_WHITE, PCT_BLACK, PCT_AMERIND, PCT_ASIAN, PCT_HAW_PACIS, PCT_OTHER_RACE, PCT_TWO_OR_MORE_RACES, HOUSINGUNITS_2010, OCCUPIEDUNITS_2010, VACANTUNITS_2010, MALE, FEMALE, AGE_LESS_5, AGE_5_TO_9, AGE_10_TO_14, AGE_15_TO_17, AGE_18_AND_19, AGE_20, AGE_21, AGE_22_TO_24, AGE_25_TO_29, AGE_30_TO_34, AGE_35_TO_39, AGE_40_TO_44, AGE_45_TO_49, AGE_50_TO_54, AGE_55_TO_59, AGE_60_AND_61, AGE_62_TO_64, AGE_65_AND_66, AGE_67_TO_69, AGE_70_TO_74, AGE_75_TO_79, AGE_80_TO_84, AGE_85_PLUS, AGE_0_TO_9, AGE_10_TO_19, AGE_20_TO_29, AGE_30_TO_39, AGE_40_TO_49, AGE_50_TO_59, AGE_60_TO_69, AGE_70_TO_79, AGE_80_PLUS, AGE_LESS_18, AGE_65_PLUS, PCT_LESS_18, PCT_65_PLUS, NUM_HOUSEHOLDS, ONE_PERSON_HH, ONE_PERSON_HH_MALE, ONE_PERSON_HH_FEMALE, TWO_OR_MORE_PERSON_HH, FAMILY_HHLD, HUSB_WIFE_FAM, HUSB_WIFE_NO_CHILD, HUSB_WIFE_W_CHLDR, OTHER_FAMILY, MALE_HHLDR_NO_WIFE, MALE_HHLDR_W_CHLDR, MALE_HHLDR_NO_CHILDR, FEMALE_HHLDR_NO_HUSB, FEMALE_HHLDR_W_CHILDR, FEMALE_HHLDR_NO_CHILDR, NON_FAMILY_HH, NON_FAMILY_MALE_HHLDR, NON_FAMILY_FEMALE_HHLDR, HH_W_NONRELATIVES, HH_NO_NONRELATIVES, FAMILIES, POP_GROUP_QRTRS, GQ_INSTITUTIONALIZED, GQ_CORRECTIONAL_FAC, GQ_JUVENILE_FAC, GQ_NURSING_FAC, GQ_OTHER_INST_FAC, GQ_NONINSTITUTIONAL, GQ_COLLEGEHOUSING, GQ_MILITARYQUARTERS, GQ_OTHER_NONINST, HOUSING_UNITS, OCCUPIED_HU, VACANT_HU, OWNED_W_MORTG_LOAN, OWNED_FREE_CLEAR, RENTED, VACANT_FOR_RENT, VACANT_RENTED_NOT_OCC, VACANT_FOR_SALE, ...]
# Index: []

# %%
# check datatypes and make sure they're appropriate (also double checks null count)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 78 entries, 1 to 78
# Columns: 126 entries, NBRHD_NAME to SHAPE_Area
# dtypes: float64(125), object(1)
# memory usage: 77.4+ KB

# %% [markdown]
# ### Drop Unnecessary Columns

# %%
df.drop(df.loc[:, 'AGE_LESS_5':'AGE_85_PLUS'], inplace = True, axis = 1)
df.drop(df.loc[:, 'PCT_HISPANIC':'VACANTUNITS_2010'], inplace = True, axis = 1)
df.drop(df.loc[:, 'NUM_HOUSEHOLDS':], inplace = True, axis = 1)
df = df.drop(['PCT_LESS_18', 'PCT_65_PLUS'], axis=1)

# %% [markdown]
# ### Format Headers

# %%
df.columns = df.columns.str.strip().str.lower().str.replace('_', ' ').str.replace(' 2010', "")
df.index.names = ['nbhd id']
df.head(1)
# Out:
#           nbrhd name  population  hispanic   white  black  nativeam  asian  \
# nbhd id
# 1        Athmar Park      8898.0    6499.0  1832.0  102.0      67.0  314.0
#
#          hawpacis  other  two or more    male  female  age 0 to 9  \
# nbhd id
# 1             8.0   14.0         62.0  4597.0  4301.0      1596.0
#
#          age 10 to 19  age 20 to 29  age 30 to 39  age 40 to 49  age 50 to 59  \
# nbhd id
# 1              1340.0        1384.0        1487.0        1123.0         893.0
#
#          age 60 to 69  age 70 to 79  age 80 plus  age less 18  age 65 plus
# nbhd id
# 1               553.0         291.0        231.0       2649.0        731.0

# %% [markdown]
# ## Visualize and Analyze the Data

# %% [markdown]
# ### Population Distribution Across the Neighborhoods

# %%
df.plot.bar(y="population", figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='nbhd id'>

# %%
rdist = df.loc[:, 'hispanic':'two or more']
rdist.head()
# Out:
#          hispanic   white  black  nativeam  asian  hawpacis  other  \
# nbhd id
# 1          6499.0  1832.0  102.0      67.0  314.0       8.0   14.0
# 2            62.0   555.0   27.0       5.0   29.0       2.0    1.0
# 3          1664.0  2854.0  144.0      43.0   52.0      10.0    7.0
# 4          4808.0  1101.0   47.0      44.0   51.0       0.0   17.0
# 5          4016.0  1151.0   40.0      53.0   81.0       2.0    5.0
#
#          two or more
# nbhd id
# 1               62.0
# 2               24.0
# 3              105.0
# 4               43.0
# 5               28.0

# %% [markdown]
# #### Total Population of Various Races in Denver

# %%
rdist.sum()
# Out:
# hispanic       190965.0
# white          313012.0
# black           58388.0
# nativeam         3525.0
# asian           19925.0
# hawpacis          495.0
# other            1208.0
# two or more     12640.0
# dtype: float64

# %%
plot = rdist.sum().plot(kind='pie', ylabel='', labeldistance=None, title='Denver Racial Distribution')
labels = [f'{i}: {round(rdist[i].sum()/rdist.sum().sum()*100, 2)}%' for i in rdist]
plot.legend(loc='center left',bbox_to_anchor=(1.0, 0.5), labels=labels)

# %% [markdown]
# #### Racial Distribution of Various Neighborhoods

# %%
# the table technically already includes this, but I recalculated it for fun
prdist = rdist.div(rdist.sum(axis=1), axis=0)
prdist
# Out:
#          hispanic     white     black  nativeam     asian  hawpacis     other  \
# nbhd id
# 1        0.730389  0.205889  0.011463  0.007530  0.035289  0.000899  0.001573
# 2        0.087943  0.787234  0.038298  0.007092  0.041135  0.002837  0.001418
# 3        0.341053  0.584956  0.029514  0.008813  0.010658  0.002050  0.001435
# 4        0.786778  0.180167  0.007691  0.007200  0.008346  0.000000  0.002782
# 5        0.747024  0.214100  0.007440  0.009859  0.015067  0.000372  0.000930
# ...           ...       ...       ...       ...       ...       ...       ...
# 74       0.618583  0.295175  0.039528  0.014168  0.015811  0.000719  0.002669
# 75       0.191686  0.757845  0.011007  0.006440  0.016979  0.000234  0.002225
# 76       0.806664  0.113909  0.016531  0.009557  0.043523  0.000194  0.002648
# 77       0.246533  0.417098  0.285655  0.004554  0.010143  0.000207  0.002277
# 78       0.206212  0.548415  0.180713  0.003019  0.035507  0.001192  0.001827
#
#          two or more
# nbhd id
# 1           0.006968
# 2           0.034043
# 3           0.021521
# 4           0.007036
# 5           0.005208
# ...              ...
# 74          0.013347
# 75          0.013583
# 76          0.006974
# 77          0.033533
# 78          0.023115
#
# [78 rows x 8 columns]

# %% [markdown]
# #### Racial Concentrations

# %%
# Which neighborhoods have higher percentage of Hispanics (relative to % in other neighborhoods)
df.loc[prdist[prdist['hispanic'] > prdist['hispanic'].mean()].index]['nbrhd name']
# Out:
# nbhd id
# 1                      Athmar Park
# 3                            Baker
# 4                           Barnum
# 5                      Barnum West
# 6                      Bear Valley
# 11                    Chaffee Park
# 17                         Clayton
# 18                            Cole
# 19     College View / South Platte
# 25                  Elyria Swansea
# 28    Gateway / Green Valley Ranch
# 29                      Globeville
# 34                     Harvey Park
# 35               Harvey Park South
# 36                        Highland
# 39                  Jefferson Park
# 41                    Lincoln Park
# 43                         Mar Lee
# 45                       Montbello
# 49             Northeast Park Hill
# 50                        Overland
# 52                           Regis
# 54                       Ruby Hill
# 56                      Sloan Lake
# 61                      Sun Valley
# 62                       Sunnyside
# 67                        Valverde
# 68                      Villa Park
# 74                     West Colfax
# 76                        Westwood
# Name: nbrhd name, dtype: object

# %%
# Which neighborhoods have higher percentage of African Americans (relative to % in other neighborhoods):
df.loc[prdist[prdist['black'] > prdist['black'].mean()].index]['nbrhd name']
# Out:
# nbhd id
# 14                       City Park
# 15                  City Park West
# 17                         Clayton
# 18                            Cole
# 23                             DIA
# 24                     East Colfax
# 26                     Five Points
# 28    Gateway / Green Valley Ranch
# 30                       Goldsmith
# 32                         Hampden
# 33                   Hampden South
# 38                    Indian Creek
# 40                         Kennedy
# 41                    Lincoln Park
# 42                     Lowry Field
# 45                       Montbello
# 46                       Montclair
# 47              North Capitol Hill
# 48                 North Park Hill
# 49             Northeast Park Hill
# 55                         Skyland
# 60                       Stapleton
# 61                      Sun Valley
# 72        Washington Virginia Vale
# 77                        Whittier
# 78                         Windsor
# Name: nbrhd name, dtype: object

# %% [markdown]
# ## Age Distribution

# %% [markdown]
# #### Population in Neighborhood Compared with Percentage of Neighborhood Population Aged 20-29

# %%
df['percent 20-29'] = round(df['age 20 to 29']/df['population']*100, 2)

ax = df.plot.line(x="nbrhd name", y='percent 20-29', label="Percentage Aged 20-29")
df.plot.bar(x="nbrhd name", y="population", figsize=(20,5), color="green", secondary_y = True, ax = ax, label="Population")
# Out:
# <AxesSubplot:label='3cf376c7-1fe5-45d3-bc42-cd2c48664d26'>

# %%
df = df.drop('percent 20-29', axis=1)

# %% [markdown]
# #### Gender Distribution

# %%
gender = df[['male', 'female']]

df[['male', 'female', 'nbrhd name']].plot.bar(figsize=(20,5), x='nbrhd name', title="Male/Female Distribution")
# Out:
# <AxesSubplot:title={'center':'Male/Female Distribution'}, xlabel='nbrhd name'>
